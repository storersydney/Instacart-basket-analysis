# %% [markdown]
# # Task 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## Contents
# #### 1. Import Libraries & Dataframe
# ####
# 2. Find the aggregated mean of the “order_number” column grouped by “department_id
# #### 3. Analyze the result
# #### 4. Create a loyalty flag for existing customers using the transform() and loc() functions
# #### 5. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category
# #### 6. Create a spending flag for each user based on the average price across all their orders
# #### 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column
# #### Extra Data Cleaning”

# %% [markdown]
# ## 1. Import Libraries & Dataframe

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import dataframe
path = r'C:\\Users\\sstorer\\OneDrive\\Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))

# %% [markdown]
# ## 2. Find the aggregated mean of the “order_number” column grouped by “department_id”

# %%
ords_prods_merge.groupby('department_id')['number_of_orders'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: number_of_orders, dtype: float64

# %% [markdown]
# ## 3. Analyze the result

# %% [markdown]
# These values represent the average number of orders per user for each department. Departments 21, 10, and 18 have the highest averages, meaning customers order from these departments more frequently. The values for the entire dataframe are very similar to those of the subset of the first million rows.

# %% [markdown]
# ## 4. Create a loyalty flag for existing customers using the transform() and loc() functions

# %%
# Create a max_order column showing the maximum number of orders for each user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_orders'].transform(np.max)
# Out:
# C:\Users\sstorer\AppData\Local\Temp\ipykernel_18304\99246066.py:2: FutureWarning: The provided callable <function max at 0x000002C839103CE0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_orders'].transform(np.max)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2539329        1                 1                   2                  8
# 2   2539329        1                 1                   2                  8
# 3   2539329        1                 1                   2                  8
# 4   2539329        1                 1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   merge_indicator    price_range_loc     busiest_day    busiest_days  \
# 0            both  Mid-range product  Regularly busy  Regularly busy
# 1            both  Mid-range product  Regularly busy  Regularly busy
# 2            both  Low-range-product  Regularly busy  Regularly busy
# 3            both  Low-range-product  Regularly busy  Regularly busy
# 4            both  Low-range-product  Regularly busy  Regularly busy
#
#   busiest_period_of_day  max_order
# 0        Average orders         10
# 1        Average orders         10
# 2        Average orders         10
# 3        Average orders         10
# 4        Average orders         10

# %%
# Create a loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# These values show the average, min, and max prices per item for each loyalty category. Loyal customers pay a lower price per item on average, and new customers pay the highest price per item on average.

# %% [markdown]
# ## 6. Create a spending flag for each user based on the average price across all their orders

# %%
# Create a column showing the average price per item for each user
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\sstorer\AppData\Local\Temp\ipykernel_18304\3534899658.py:2: FutureWarning: The provided callable <function mean at 0x000002C839118720> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2539329        1                 1                   2                  8
# 2   2539329        1                 1                   2                  8
# 3   2539329        1                 1                   2                  8
# 4   2539329        1                 1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    ... department_id  prices  merge_indicator    price_range_loc  \
# 0  ...             7     9.0             both  Mid-range product
# 1  ...            16    12.5             both  Mid-range product
# 2  ...            19     4.4             both  Low-range-product
# 3  ...            19     4.7             both  Low-range-product
# 4  ...            17     1.0             both  Low-range-product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average orders        10
# 1  Regularly busy  Regularly busy        Average orders        10
# 2  Regularly busy  Regularly busy        Average orders        10
# 3  Regularly busy  Regularly busy        Average orders        10
# 4  Regularly busy  Regularly busy        Average orders        10
#
#    loyalty_flag  avg_price
# 0  New customer   6.367797
# 1  New customer   6.367797
# 2  New customer   6.367797
# 3  New customer   6.367797
# 4  New customer   6.367797
#
# [5 rows x 22 columns]

# %%
# Create a spending flag
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2539329        1                 1                   2                  8
# 2   2539329        1                 1                   2                  8
# 3   2539329        1                 1                   2                  8
# 4   2539329        1                 1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#    ... prices  merge_indicator    price_range_loc     busiest_day  \
# 0  ...    9.0             both  Mid-range product  Regularly busy
# 1  ...   12.5             both  Mid-range product  Regularly busy
# 2  ...    4.4             both  Low-range-product  Regularly busy
# 3  ...    4.7             both  Low-range-product  Regularly busy
# 4  ...    1.0             both  Low-range-product  Regularly busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag avg_price  \
# 0  Regularly busy        Average orders        10  New customer  6.367797
# 1  Regularly busy        Average orders        10  New customer  6.367797
# 2  Regularly busy        Average orders        10  New customer  6.367797
# 3  Regularly busy        Average orders        10  New customer  6.367797
# 4  Regularly busy        Average orders        10  New customer  6.367797
#
#    spending_flag
# 0    Low spender
# 1    Low spender
# 2    Low spender
# 3    Low spender
# 4    Low spender
#
# [5 rows x 23 columns]

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# %%
# Create a column showing the median days since prior order for each user
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\sstorer\AppData\Local\Temp\ipykernel_18304\939689060.py:2: FutureWarning: The provided callable <function median at 0x000002C839268360> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Create an order frequency flag that marks regularity of a user's ordering behavior
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <= 20), 'order_frequency'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2539329        1                 1                   2
# 2    2539329        1                 1                   2
# 3    2539329        1                 1                   2
# 4    2539329        1                 1                   2
# 5    2398795        1                 2                   3
# 6    2398795        1                 2                   3
# 7    2398795        1                 2                   3
# 8    2398795        1                 2                   3
# 9    2398795        1                 2                   3
# 10   2398795        1                 2                   3
# 11    473747        1                 3                   3
# 12    473747        1                 3                   3
# 13    473747        1                 3                   3
# 14    473747        1                 3                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   8                     NaN       14084                  2
# 2                   8                     NaN       12427                  3
# 3                   8                     NaN       26088                  4
# 4                   8                     NaN       26405                  5
# 5                   7                    15.0         196                  1
# 6                   7                    15.0       10258                  2
# 7                   7                    15.0       12427                  3
# 8                   7                    15.0       13176                  4
# 9                   7                    15.0       26088                  5
# 10                  7                    15.0       13032                  6
# 11                 12                    21.0         196                  1
# 12                 12                    21.0       12427                  2
# 13                 12                    21.0       10258                  3
# 14                 12                    21.0       25133                  4
#
#     reordered _merge  ...    price_range_loc     busiest_day    busiest_days  \
# 0           0   both  ...  Mid-range product  Regularly busy  Regularly busy
# 1           0   both  ...  Mid-range product  Regularly busy  Regularly busy
# 2           0   both  ...  Low-range-product  Regularly busy  Regularly busy
# 3           0   both  ...  Low-range-product  Regularly busy  Regularly busy
# 4           0   both  ...  Low-range-product  Regularly busy  Regularly busy
# 5           1   both  ...  Mid-range product  Regularly busy    Slowest days
# 6           0   both  ...  Low-range-product  Regularly busy    Slowest days
# 7           1   both  ...  Low-range-product  Regularly busy    Slowest days
# 8           0   both  ...  Mid-range product  Regularly busy    Slowest days
# 9           1   both  ...  Low-range-product  Regularly busy    Slowest days
# 10          0   both  ...  Low-range-product  Regularly busy    Slowest days
# 11          1   both  ...  Mid-range product  Regularly busy    Slowest days
# 12          1   both  ...  Low-range-product  Regularly busy    Slowest days
# 13          1   both  ...  Low-range-product  Regularly busy    Slowest days
# 14          0   both  ...  Mid-range product  Regularly busy    Slowest days
#
#     busiest_period_of_day max_order  loyalty_flag avg_price spending_flag  \
# 0          Average orders        10  New customer  6.367797   Low spender
# 1          Average orders        10  New customer  6.367797   Low spender
# 2          Average orders        10  New customer  6.367797   Low spender
# 3          Average orders        10  New customer  6.367797   Low spender
# 4          Average orders        10  New customer  6.367797   Low spender
# 5          Average orders        10  New customer  6.367797   Low spender
# 6          Average orders        10  New customer  6.367797   Low spender
# 7          Average orders        10  New customer  6.367797   Low spender
# 8          Average orders        10  New customer  6.367797   Low spender
# 9          Average orders        10  New customer  6.367797   Low spender
# 10         Average orders        10  New customer  6.367797   Low spender
# 11            Most orders        10  New customer  6.367797   Low spender
# 12            Most orders        10  New customer  6.367797   Low spender
# 13            Most orders        10  New customer  6.367797   Low spender
# 14            Most orders        10  New customer  6.367797   Low spender
#
#    median_days_since_prior_order        order_frequency
# 0                           20.5  Non-frequent customer
# 1                           20.5  Non-frequent customer
# 2                           20.5  Non-frequent customer
# 3                           20.5  Non-frequent customer
# 4                           20.5  Non-frequent customer
# 5                           20.5  Non-frequent customer
# 6                           20.5  Non-frequent customer
# 7                           20.5  Non-frequent customer
# 8                           20.5  Non-frequent customer
# 9                           20.5  Non-frequent customer
# 10                          20.5  Non-frequent customer
# 11                          20.5  Non-frequent customer
# 12                          20.5  Non-frequent customer
# 13                          20.5  Non-frequent customer
# 14                          20.5  Non-frequent customer
#
# [15 rows x 25 columns]

# %%
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# ## Extra Data Cleaning

# %%
# Find items with prices higher than 100 (outliers)
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  number_of_orders  orders_day_of_week  \
# 1576        912404       17                12                   2
# 1638        603376       17                22                   6
# 16522      3264360      135                 2                   2
# 16528       892534      135                 3                   0
# 53672       229704      342                 8                   1
# ...            ...      ...               ...                 ...
# 32320511   3172853   205650                18                   1
# 32347717   2504315   205818                 3                   5
# 32347727   1108388   205818                 5                   4
# 32380527   1916142   206049                 1                   2
# 32380551    379732   206049                 4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 1576                     14                     5.0       21553
# 1638                     16                     4.0       21553
# 16522                    21                    13.0       21553
# 16528                     8                    12.0       21553
# 53672                    19                    30.0       21553
# ...                     ...                     ...         ...
# 32320511                  9                     7.0       21553
# 32347717                 15                     3.0       21553
# 32347727                  5                     1.0       21553
# 32380527                 17                     NaN       21553
# 32380551                 14                     5.0       21553
#
#           add_to_cart_order  reordered _merge  ...     price_range_loc  \
# 1576                      5          0   both  ...  High-range product
# 1638                      3          1   both  ...  High-range product
# 16522                     6          0   both  ...  High-range product
# 16528                     3          1   both  ...  High-range product
# 53672                     9          0   both  ...  High-range product
# ...                     ...        ...    ...  ...                 ...
# 32320511                 17          1   both  ...  High-range product
# 32347717                 13          0   both  ...  High-range product
# 32347727                  5          1   both  ...  High-range product
# 32380527                  2          0   both  ...  High-range product
# 32380551                  4          1   both  ...  High-range product
#
#              busiest_day    busiest_days  busiest_period_of_day max_order  \
# 1576      Regularly busy  Regularly busy            Most orders        40
# 1638      Regularly busy  Regularly busy            Most orders        40
# 16522     Regularly busy  Regularly busy         Average orders         4
# 16528        Busiest day    Busiest days         Average orders         4
# 53672     Regularly busy    Busiest days         Average orders        16
# ...                  ...             ...                    ...       ...
# 32320511  Regularly busy    Busiest days            Most orders        25
# 32347717  Regularly busy  Regularly busy            Most orders        25
# 32347727      Least busy    Slowest days          Fewest orders        25
# 32380527  Regularly busy  Regularly busy         Average orders         5
# 32380551  Regularly busy    Busiest days            Most orders         5
#
#               loyalty_flag    avg_price spending_flag  \
# 1576      Regular customer   108.648299  High spender
# 1638      Regular customer   108.648299  High spender
# 16522         New customer  1154.792308  High spender
# 16528         New customer  1154.792308  High spender
# 53672     Regular customer   114.426619  High spender
# ...                    ...          ...           ...
# 32320511  Regular customer   351.141618  High spender
# 32347717  Regular customer   170.073770  High spender
# 32347727  Regular customer   170.073770  High spender
# 32380527      New customer   938.031250  High spender
# 32380551      New customer   938.031250  High spender
#
#          median_days_since_prior_order        order_frequency
# 1576                               5.0      Frequent customer
# 1638                               5.0      Frequent customer
# 16522                             12.0       Regular customer
# 16528                             12.0       Regular customer
# 53672                             23.0  Non-frequent customer
# ...                                ...                    ...
# 32320511                           6.0      Frequent customer
# 32347717                          13.0       Regular customer
# 32347727                          13.0       Regular customer
# 32380527                           7.0      Frequent customer
# 32380551                           7.0      Frequent customer
#
# [5127 rows x 25 columns]

# %%
# Assign Nan values to outliers
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# Drop merge flag columns
ords_prods_merge = ords_prods_merge.drop('_merge', axis=1)
ords_prods_merge = ords_prods_merge.drop('merge_indicator', axis = 1)

# %%
# Set to display all columns
pd.set_option('display.max_columns', None)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2539329        1                 1                   2                  8
# 2   2539329        1                 1                   2                  8
# 3   2539329        1                 1                   2                  8
# 4   2539329        1                 1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Low-range-product  Regularly busy  Regularly busy        Average orders
# 3  Low-range-product  Regularly busy  Regularly busy        Average orders
# 4  Low-range-product  Regularly busy  Regularly busy        Average orders
#
#    max_order  loyalty_flag  avg_price spending_flag  \
# 0         10  New customer   6.367797   Low spender
# 1         10  New customer   6.367797   Low spender
# 2         10  New customer   6.367797   Low spender
# 3         10  New customer   6.367797   Low spender
# 4         10  New customer   6.367797   Low spender
#
#    median_days_since_prior_order        order_frequency
# 0                           20.5  Non-frequent customer
# 1                           20.5  Non-frequent customer
# 2                           20.5  Non-frequent customer
# 3                           20.5  Non-frequent customer
# 4                           20.5  Non-frequent customer

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_grouped.pkl'))
